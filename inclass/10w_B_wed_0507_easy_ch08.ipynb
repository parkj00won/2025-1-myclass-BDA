# %% [markdown]
# <a href="https://colab.research.google.com/github/parkj00won/2025-1-myclass-BDA/blob/main/inclass/10w_B_wed_0507_easy_ch08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 단원 08 그래프 만들기

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install koreanize-matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 43.3 MB/s eta 0:00:00
# ...

# %%
# %config InlineBackend.figure_format = 'retina'

# %%
pd.set_option('display.precision', 2)

# %%
# !git clone https://github.com/ai7dnn/data
# Out:
# Cloning into 'data'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 24 (delta 4), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (24/24), 2.14 MiB | 5.42 MiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %%
mpg=pd.read_csv('data/mpg.csv')
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  category      234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 20.2+ KB

# %%
mpg.isna().sum()
# Out:
# manufacturer    0
# model           0
# displ           0
# year            0
# cyl             0
# trans           0
# drv             0
# cty             0
# hwy             0
# fl              0
# category        0
# dtype: int64

# %%
mpg.isna().sum().sum()
# Out:
# np.int64(0)

# %%
plt.rcParams['figure.figsize'] = [4, 2.5]

# %%
import koreanize_matplotlib

sns.scatterplot(data=mpg, x='displ', y='hwy')
# Out:
# <Axes: xlabel='displ', ylabel='hwy'>

# %%
sns.scatterplot(data=mpg, x='displ', y='hwy', alpha= .3)
# Out:
# <Axes: xlabel='displ', ylabel='hwy'>

# %%
sns.scatterplot(data=mpg, x='displ', y='hwy', alpha= .3).set(xlim=[3,6], ylim=[15, 30]);

# %%
sns.scatterplot(data=mpg, x='displ', y='hwy', hue='drv', alpha= .3)
# Out:
# <Axes: xlabel='displ', ylabel='hwy'>

# %%
sns.scatterplot(data=mpg, x='displ', y='hwy', hue='category');

# %%
sns.scatterplot(data=mpg, x='displ', y='hwy', hue='category');
plt.legend(loc='upper right');

# %%
sns.scatterplot(data=mpg, x='displ', y='hwy', hue='category');
plt.legend(loc='lower right',bbox_to_anchor=(1, 1));

# %%
sns.scatterplot(data=mpg, x='displ', y='hwy', hue='category');
plt.legend(loc='upper right',bbox_to_anchor=(1, 1));

# %%
sns.scatterplot(data=mpg, x='displ', y='hwy', hue='drv')
plt.legend(loc=4);

# %% [markdown]
# | **숫자 값** | **문자열 값**      | **위치**         |
# | -------- | -------------- | -------------- |
# | 0        | 'best'         | 자동으로 가장 적합한 위치 |
# | 1        | 'upper right'  | 우측 상단          |
# | 2        | 'upper left'   | 좌측 상단          |
# | 3        | 'lower left'   | 좌측 하단          |
# | 4        | 'lower right'  | 우측 하단          |
# | 5        | 'right'        | 오른쪽            |
# | 6        | 'center left'  | 왼쪽 중앙          |
# | 7        | 'center right' | 오른쪽 중앙         |
# | 8        | 'lower center' | 하단 중앙          |
# | 9        | 'upper center' | 상단 중앙          |
# | 10       | 'center'       | 중앙             |

# %%
sns.scatterplot(data=mpg, x='displ', y='hwy', hue='category');
plt.legend(loc='upper right',bbox_to_anchor=(0, 1));

# %%
sns.scatterplot(data=mpg, x='displ', y='hwy', hue='category');
plt.legend(loc='upper left',bbox_to_anchor=(1, 1));

# %%
sns.scatterplot(data=mpg, x='trans', y='hwy', hue='hwy');

# %%
sns.scatterplot(data=mpg, x='trans', y='hwy', hue='hwy');
plt.legend(loc='upper left',bbox_to_anchor=(1, 0));

# %%
myPlot = sns.scatterplot(data=mpg, x='trans', y='hwy', hue='hwy');
myPlot.tick_params(axis='x', labelrotation=45);
myPlot.legend(loc='upper left',bbox_to_anchor=(1, 0));

# %%
df_mpg = mpg.groupby('drv').agg(mean_hwy=('hwy', 'mean'))
df_mpg
# Out:
#      mean_hwy
# drv
# 4       19.17
# f       28.16
# r       21.00

# %%
sns.barplot(data=df_mpg, x='drv', y='mean_hwy');

# %%
sns.barplot(data=df_mpg, x='drv', y='mean_hwy', hue = 'drv');

# %%
sns.barplot(data=df_mpg, x='drv', y='mean_hwy', hue ='drv', order=['f','r','4']);

# %%
sns.barplot(data=mpg, x='drv', y='hwy', hue='fl', order=['f', 'r', '4'])
# Out:
# <Axes: xlabel='drv', ylabel='hwy'>

# %%
mpg.groupby('drv', as_index=False).count()[['drv', 'model']]
# Out:
#   drv  model
# 0   4    103
# 1   f    106
# 2   r     25

# %%
mpg.groupby('drv', as_index=False).count()[['drv', 'model']].rename(columns={'model':'n'})
# Out:
#   drv    n
# 0   4  103
# 1   f  106
# 2   r   25

# %%
df_mpg = mpg.groupby('drv', as_index=False).agg(n =('drv', 'count'))
df_mpg
# Out:
#   drv    n
# 0   4  103
# 1   f  106
# 2   r   25

# %%
df_mpg2 = mpg.groupby('drv').agg(n =('drv', 'count'))
df_mpg2
# Out:
#        n
# drv
# 4    103
# f    106
# r     25

# %%
sns.barplot(data=df_mpg, x='drv', y='n', hue='drv');

# %%
sns.countplot(data=mpg, x='drv');

# %%
sns.countplot(data=mpg, x='drv', hue='drv');

# %%
mpg.drv.value_counts().index
# Out:
# Index(['f', '4', 'r'], dtype='object', name='drv')

# %%
sns.countplot

# %% [markdown]
# ###주요 컬럼 소개

# %%
# !git clone https://github.com/ai7dnn/data
# Out:
# fatal: destination path 'data' already exists and is not an empty directory.

# %%
eco = pd.read_csv('data/economics.csv')
eco.info()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-64-f292bebf8106> in <cell line: 0>()
# ----> 1 eco = pd.read_csv('data/economics.csv');
#       2 eco.info()
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
eco,head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-15182638d5b8> in <cell line: 0>()
# ----> 1 eco,head()
#
# NameError: name 'eco' is not defined

# %%
eco.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-323da17a11f7> in <cell line: 0>()
# ----> 1 eco.shape
#
# NameError: name 'eco' is not defined

# %%
sns.lineplot(data=eco, x='date', y='unemploy');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-bb25349fa297> in <cell line: 0>()
# ----> 1 sns.lineplot(data=eco, x='date', y='unemploy');
#
# NameError: name 'eco' is not defined

# %%
sns.lineplot(data=eco, x=pd.to_dateime(eco['date']), y='unemploy');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-aa3224c62611> in <cell line: 0>()
# ----> 1 sns.lineplot(data=eco, x=pd.to_dateime(eco['date']), y='unemploy');
#
# NameError: name 'eco' is not defined

# %%
eco.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-6741ed5d937c> in <cell line: 0>()
# ----> 1 eco.info()
#
# NameError: name 'eco' is not defined

# %%
eco['date2'] = pd.to_datetime(eco['date'])
eco.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-a69628a7db2b> in <cell line: 0>()
# ----> 1 eco['date2'] = pd.to_datetime(eco['date'])
#       2 eco.info()
#
# NameError: name 'eco' is not defined

# %%
eco[['date', 'date2']].info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-b576c4eda5f6> in <cell line: 0>()
# ----> 1 eco[['date', 'date2']].info()
#
# NameError: name 'eco' is not defined

# %%
eco[date2].dt.year
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-3c487565791c> in <cell line: 0>()
# ----> 1 eco[date2].dt.year
#
# NameError: name 'eco' is not defined

# %%
eco[date2].dt.day
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-fdc42c673f07> in <cell line: 0>()
# ----> 1 eco[date2].dt.day
#
# NameError: name 'eco' is not defined

# %%
eco['year'] = eco[date2].dt.year
eco['month'] = eco[date2].dt.month
eco['day'] = eco[date2].dt.day
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-5bcb6e5351f1> in <cell line: 0>()
# ----> 1 eco['year'] = eco[date2].dt.year
#       2 eco['month'] = eco[date2].dt.month
#       3 eco['day'] = eco[date2].dt.day
#
# NameError: name 'eco' is not defined

# %%
sns.lineplot(data=eco, x='date2', y='unemploy');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-69-31ba6a06488d> in <cell line: 0>()
# ----> 1 sns.lineplot(data=eco, x='date2', y='unemploy');
#
# NameError: name 'eco' is not defined

# %%
sns.lineplot(data=eco, x=eco['year'], y='unemploy', errorbar=None);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-821bd1dab85a> in <cell line: 0>()
# ----> 1 sns.lineplot(data=eco, x=eco['year'], y='unemploy', errorbar=None);
#
# NameError: name 'eco' is not defined

# %%
plt.rcParams.update({})

# %%
mpg.query('fl == "e"')
# Out:
#     manufacturer                model  displ  year  cyl       trans drv  cty  \
# 19     chevrolet   c1500 suburban 2wd    5.3  2008    8    auto(l4)   r   11
# 29     chevrolet      k1500 tahoe 4wd    5.3  2008    8    auto(l4)   4   11
# 43         dodge          caravan 2wd    3.3  2008    6    auto(l4)   f   11
# 54         dodge    dakota pickup 4wd    4.7  2008    8    auto(l5)   4    9
# 59         dodge          durango 4wd    4.7  2008    8    auto(l5)   4    9
# 65         dodge  ram 1500 pickup 4wd    4.7  2008    8    auto(l5)   4    9
# 69         dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4    9
# 126         jeep   grand cherokee 4wd    4.7  2008    8    auto(l5)   4    9
#
#      hwy fl category
# 19    15  e      suv
# 29    14  e      suv
# 43    17  e  minivan
# 54    12  e   pickup
# 59    12  e      suv
# 65    12  e   pickup
# 69    12  e   pickup
# 126   12  e      suv

# %% [markdown]
# ## 08 단원 종료
