# %% [markdown]
# <a href="https://colab.research.google.com/github/parkj00won/2025-1-myclass-BDA/blob/main/inclass/05w_B_wed_0402_easy_ch05_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ai7dnn/data.git
# Out:
# Cloning into 'data'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 24 (delta 4), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (24/24), 2.14 MiB | 6.00 MiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %%
import pandas as pd
exam = pd.read_csv("data/exam.csv")

# %%
exam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       20 non-null     int64
#  1   nclass   20 non-null     int64
#  2   math     20 non-null     int64
#  3   english  20 non-null     int64
#  4   science  20 non-null     int64
# dtypes: int64(5)
# memory usage: 932.0 bytes

# %%
df_raw = pd.DataFrame({'var1' : [1, 2, 1],
                       'var2' : [2, 3, 2],
                       'var3' : [10, 20, 30]})
df_raw
# Out:
#    var1  var2  var3
# 0     1     2    10
# 1     2     3    20
# 2     1     2    30

# %%
df_new = df_raw.copy()
df_new
# Out:
#    var1  var2  var3
# 0     1     2    10
# 1     2     3    20
# 2     1     2    30

# %% [markdown]
# ### 중간고사 문제 (05-2 변수명 바꾸기(p113): 시험예상)

# %%
df_new.rename(columns = {'var2' : 'v2'})  #중요
# Out:
#    var1  v2  var3
# 0     1   2    10
# 1     2   3    20
# 2     1   2    30

# %%
df_new
# Out:
#    var1  var2  var3
# 0     1     2    10
# 1     2     3    20
# 2     1     2    30

# %%
df_new.rename(columns = {'var2': 'v2'}, inplace=True) # 중요
df_new
# Out:
#    var1  v2  var3
# 0     1   2    10
# 1     2   3    20
# 2     1   2    30

# %%
df_raw
# Out:
#    var1  var2  var3
# 0     1     2    10
# 1     2     3    20
# 2     1     2    30

# %%
df = pd.DataFrame({"A": [1, 2, 3], "B": [4, 5, 6]})
df.rename(columns={"A": "a", "B": "c"})
# Out:
#    a  c
# 0  1  4
# 1  2  5
# 2  3  6

# %%
df
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %% [markdown]
# ### 05-3 파생변수 만들기: 시험예상

# %%
df = pd.DataFrame({'var1' : [4, 3, 8],
                   'var2' : [2, 6, 1]})
df
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df1 = df.copy()
df1
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df1['var_sum'] = df1['var1'] + df1['var2']
df1
# Out:
#    var1  var2  var_sum
# 0     4     2        6
# 1     3     6        9
# 2     8     1        9

# %%
# 새로운 열 var_mean <- var1과 var2의 평균
df1["var_mean"] = (df1["var1"] + df1["var2"]) / 2
df1
# Out:
#    var1  var2  var_sum  var_mean
# 0     4     2        6       3.0
# 1     3     6        9       4.5
# 2     8     1        9       4.5

# %%
df2 = df.copy()
df2
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df2.sum()
# Out:
# var1    15
# var2     9
# dtype: int64

# %%
df2.sum(axis=1)
# Out:
# 0    6
# 1    9
# 2    9
# dtype: int64

# %%
df2['my_sum'] = df2.sum(axis='columns')
df2
# Out:
#    var1  var2  my_sum
# 0     4     2       6
# 1     3     6       9
# 2     8     1       9

# %%
df2[["var1","var2"]]
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
# 새로운 열 var_mean <- var1과 var2의 평균
df2["my_mean"] = df2[["var1","var2"]].mean(axis=1) # 시험 예상
df2
# Out:
#    var1  var2  my_sum  my_mean
# 0     4     2       6      3.0
# 1     3     6       9      4.5
# 2     8     1       9      4.5

# %%
df1
# Out:
#    var1  var2  var_sum  var_mean
# 0     4     2        6       3.0
# 1     3     6        9       4.5
# 2     8     1        9       4.5

# %% [markdown]
# ## mpg 통합 연비 변수 생성

# %%
# mpg 데이터 불러오기
mpg = pd.read_csv('data/mpg.csv')
mpg.sample(8)
# Out:
#     manufacturer              model  displ  year  cyl       trans drv  cty  \
# 63         dodge        durango 4wd    5.9  1999    8    auto(l4)   4   11
# 9           audi         a4 quattro    2.0  2008    4  manual(m6)   4   20
# 52         dodge  dakota pickup 4wd    4.7  2008    8    auto(l5)   4   14
# 170       subaru        impreza awd    2.5  2008    4    auto(s4)   4   20
# 177       toyota        4runner 4wd    4.0  2008    6    auto(l5)   4   16
# 11          audi         a4 quattro    2.8  1999    6    auto(l5)   4   15
# 132   land rover        range rover    4.4  2008    8    auto(s6)   4   12
# 148       nissan             maxima    3.0  1999    6  manual(m5)   f   19
#
#      hwy fl category
# 63    15  r      suv
# 9     28  p  compact
# 52    19  r   pickup
# 170   27  r  compact
# 177   20  r      suv
# 11    25  p  compact
# 132   18  r      suv
# 148   25  r  midsize

# %%
mpg = pd.read_csv('data/mpg.csv')
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  category      234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 20.2+ KB

# %%
mpg.sample(3)
# Out:
#     manufacturer               model  displ  year  cyl       trans drv  cty  \
# 57         dodge         durango 4wd    3.9  1999    6    auto(l4)   4   13
# 21     chevrolet  c1500 suburban 2wd    5.7  1999    8    auto(l4)   r   13
# 121      hyundai             tiburon    2.7  2008    6  manual(m5)   f   17
#
#      hwy fl    category
# 57    17  r         suv
# 21    17  r         suv
# 121   24  r  subcompact

# %%
mpg.total = (mpg.cty + mpg.hwy) / 2
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
mpg['total'] = (mpg.cty + mpg.hwy) / 2
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    total
# 0   23.5
# 1   25.0
# 2   25.5
# 3   25.5
# 4   21.0

# %%
mpg['mpg_mean'] = mpg[['cty','hwy']].mean(axis='columns')
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    total  mpg_mean
# 0   23.5      23.5
# 1   25.0      25.0
# 2   25.5      25.5
# 3   25.5      25.5
# 4   21.0      21.0

# %%
sum(mpg.total)
# Out:
# 4715.0

# %%
sum(mpg.total) / len(mpg)
# Out:
# 20.14957264957265

# %%
mpg['total'].mean()
# Out:
# np.float64(20.14957264957265)

# %%
mpg.total.mean()
# Out:
# np.float64(20.14957264957265)

# %% [markdown]
# ### 조건문을 활용해 파생변수 만들기 (p118)

# %%
mpg.total.describe()
# Out:
# count    234.000000
# mean      20.149573
# std        5.050290
# min       10.500000
# 25%       15.500000
# 50%       20.500000
# 75%       23.500000
# max       39.500000
# dtype: float64

# %%
mpg.total.plot.hist();

# %%
mpg['total'].plot(kind="hist", title="히스토그램"); #깨짐
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 55176 (\N{HANGUL SYLLABLE HI}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 49828 (\N{HANGUL SYLLABLE SEU}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 53664 (\N{HANGUL SYLLABLE TO}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 47016 (\N{HANGUL SYLLABLE RAEM}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# ...

# %%
# !pip install koreanize-matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 36.1 MB/s eta 0:00:00
# ...

# %%
import koreanize_matplotlib

# %%
mpg['total'].plot(kind="hist", title="히스토그램"); # 아직 흐리게 보임

# %%
# %config InlineBackend.figure_format = 'retina' #선명하게

# %%
mpg['total'].plot(kind="hist", title="히스토그램");

# %%
import seaborn as sns

sns.histplot(mpg, x="total"); # x=mpg.total
